# %%
print("hello")
# Out:
# hello

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('dog_backpack.jpg')
img
img2=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
img3=cv2.imread('watermark_no_copy.png')
img3
img4=cv2.cvtColor(img3,cv2.COLOR_BGR2RGB)
plt.imshow(img4)

# %%
img5=cv2.resize(img2,(1200,1200))
img6=cv2.resize(img4,(1200,1200))

# %%
img7=cv2.addWeighted(img5,0.5,img6,0.5,0)
plt.imshow(img7)

# %%
img=cv2.imread('dog_backpack.jpg')
img
img2=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
img3=cv2.imread('watermark_no_copy.png')
img3
img4=cv2.cvtColor(img3,cv2.COLOR_BGR2RGB)
plt.imshow(img4)

# %%
#import numpy as np

# %%
img2.shape
# Out:
# (1401, 934, 3)

# %%
img4.shape
# Out:
# (1280, 1277, 3)

# %%
img4=cv2.resize(img4, (600,600))
plt.imshow(img4)

# %%
img2[0:600,0:600]=img4
plt.imshow(img2)
